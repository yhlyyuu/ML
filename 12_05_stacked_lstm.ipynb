# %% [markdown]
# <a href="https://colab.research.google.com/github/yhlyyuu/ML/blob/main/12_05_stacked_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 時間序列(Time Series)預測
# ### 程式修改自 [Time Series Prediction with LSTM Recurrent Neural Networks in Python with Keras](https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/)

# %%
# 載入相關套件
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

file_path = '/content/AirPassengers.csv'
if os.path.exists(file_path):
    df2 = pd.read_csv(file_path)
    print("File loaded successfully!")
else:
    print("File not found. Please check the file path and name.")
# Out:
# File loaded successfully!

# %%
# 載入測試資料
df2 = pd.read_csv('/content/AirPassengers.csv')
df2.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df2.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
# 繪圖
df2 = df2.set_index('Month')
df2.plot(legend=None)
plt.xticks(rotation=30)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120., 140., 160.]),
#  [Text(-20.0, 0, '1959-05'),
#   Text(0.0, 0, '1949-01'),
#   Text(20.0, 0, '1950-09'),
#   Text(40.0, 0, '1952-05'),
#   Text(60.0, 0, '1954-01'),
#   Text(80.0, 0, '1955-09'),
#   Text(100.0, 0, '1957-05'),
#   Text(120.0, 0, '1959-01'),
#   Text(140.0, 0, '1960-09'),
#   Text(160.0, 0, '')])

# %%
# 轉換資料
from sklearn.preprocessing import MinMaxScaler

# 函數：以前期資料為 X，當前期資料為 Y
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

dataset = df2.values
dataset = dataset.astype('float32')

# X 常態化
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# 資料分割
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# 以前期資料為 X，當期資料為 Y

look_back = 10 # 設置 look_back 值
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# 確保數據形狀一致
print(f'trainX shape: {trainX.shape}, trainY shape: {trainY.shape}')
print(f'testX shape: {testX.shape}, testY shape: {testY.shape}')

# 轉換為三維 [筆數, 落後期數, X維度]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# Out:
# trainX shape: (85, 10), trainY shape: (85,)
# testX shape: (37, 10), testY shape: (37,)

# %%
from keras.layers import LSTM, Dense, Dropout
# 建立 LSTM 模型

# 建立改進的 LSTM 模型
model_lstm = Sequential()
model_lstm.add(LSTM(200, return_sequences=True, input_shape=(1, look_back)))# 添加多層 LSTM
model_lstm.add(Dropout(0.3)) # 添加 Dropout 層
model_lstm.add(LSTM(100))
model_lstm.add(Dropout(0.3))
model_lstm.add(Dense(1))

model_lstm.compile(loss='mean_squared_error', optimizer='adam')

# 訓練 LSTM 模型
model_lstm.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)


# 模型評估
trainPredict = model_lstm.predict(trainX)
testPredict = model_lstm.predict(testX)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0227
# Epoch 2/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061
# Epoch 3/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049
# Epoch 4/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0047
# Epoch 5/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050
# Epoch 6/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0039
# Epoch 7/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0035
# Epoch 8/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032
# Epoch 9/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0032
# Epoch 10/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033
# Epoch 11/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029
# Epoch 12/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031
# Epoch 13/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047
# Epoch 14/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0024
# Epoch 15/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044
# Epoch 16/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028
# Epoch 17/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0030
# Epoch 18/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0022
# Epoch 19/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027
# Epoch 20/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026
# Epoch 21/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031
# Epoch 22/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0024
# Epoch 23/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029
# Epoch 24/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 25/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031
# Epoch 26/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0031
# Epoch 27/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 28/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0023
# Epoch 29/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030
# Epoch 30/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0022
# Epoch 31/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0025
# Epoch 32/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 33/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 34/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030
# Epoch 35/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0024
# Epoch 36/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0020
# Epoch 37/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 38/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028
# Epoch 39/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031
# Epoch 40/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0023
# Epoch 41/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028
# Epoch 42/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0025
# Epoch 43/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030
# Epoch 44/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029
# Epoch 45/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 46/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 47/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 48/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 49/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 50/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0015
# Epoch 51/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028
# Epoch 52/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 53/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 54/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 55/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031
# Epoch 56/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0019
# Epoch 57/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0024
# Epoch 58/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0020
# Epoch 59/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018
# Epoch 60/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0017
# Epoch 61/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 62/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 63/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 64/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016
# Epoch 65/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0020
# Epoch 66/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 67/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0026
# Epoch 68/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0023
# Epoch 69/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 70/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029
# Epoch 71/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0019
# Epoch 72/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 73/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0016
# Epoch 74/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0013
# Epoch 75/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 76/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 77/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 78/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016
# Epoch 79/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029
# Epoch 80/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0013
# Epoch 81/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# Epoch 82/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 83/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0022
# Epoch 84/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 85/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 86/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016
# Epoch 87/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0017
# Epoch 88/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 89/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 90/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 91/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 92/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0011
# Epoch 93/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 94/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016
# Epoch 95/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0017
# Epoch 96/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 97/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027
# Epoch 98/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016
# Epoch 99/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036
# Epoch 100/100
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
from sklearn.metrics import mean_squared_error
import math

# 還原常態化的訓練及測試資料
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# 計算 RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# 訓練資料的 X/Y
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# 測試資料 X/Y
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# 繪圖
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 17.79 RMSE
# Test Score: 38.23 RMSE

# %% [markdown]
# ## 改變Loopback=3：X由前1期改為前3期

# %%
# 載入測試資料
df = pd.read_csv('/content/AirPassengers.csv', usecols=[1])
print(df.head())
dataset = df.values
dataset = dataset.astype('float32')

# X 常態化
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# 資料分割
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# 以前期資料為 X，當前期資料為 Y
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)



# Reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
# Out:
#    #Passengers
# 0          112
# 1          118
# 2          132
# 3          129
# 4          121

# %%
dataset
# Out:
# array([[0.01544401],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853],
#        [0.05984557],
#        [0.08494207],
#        [0.08494207],
#        [0.06177607],
#        [0.02895753],
#        [0.        ],
#        [0.02702703],
#        [0.02123553],
#        [0.04247104],
#        [0.07142857],
#        [0.05984557],
#        [0.04054055],
#        [0.08687258],
#        [0.12741312],
#        [0.12741312],
#        [0.10424709],
#        [0.05598456],
#        [0.01930502],
#        [0.06949806],
#        [0.07915059],
#        [0.08880308],
#        [0.14285713],
#        [0.11389962],
#        [0.13127413],
#        [0.14285713],
#        [0.18339768],
#        [0.18339768],
#        [0.15444016],
#        [0.11196911],
#        [0.08108109],
#        [0.1196911 ],
#        [0.12934363],
#        [0.14671814],
#        [0.17181468],
#        [0.14864865],
#        [0.15250966],
#        [0.22007722],
#        [0.24324325],
#        [0.26640925],
#        [0.2027027 ],
#        [0.16795367],
#        [0.13127413],
#        [0.17374519],
#        [0.17760617],
#        [0.17760617],
#        [0.25482625],
#        [0.25289574],
#        [0.24131274],
#        [0.26833975],
#        [0.3088803 ],
#        [0.32432434],
#        [0.25675675],
#        [0.20656371],
#        [0.14671814],
#        [0.18725869],
#        [0.19305018],
#        [0.16216215],
#        [0.25289574],
#        [0.23745173],
#        [0.25096524],
#        [0.3088803 ],
#        [0.38223937],
#        [0.36486486],
#        [0.2992278 ],
#        [0.24131274],
#        [0.1911197 ],
#        [0.24131274],
#        [0.26640925],
#        [0.24903473],
#        [0.31467178],
#        [0.3185328 ],
#        [0.32046333],
#        [0.4073359 ],
#        [0.5019305 ],
#        [0.46911195],
#        [0.40154442],
#        [0.32818535],
#        [0.25675675],
#        [0.3359073 ],
#        [0.34749034],
#        [0.33397684],
#        [0.41119692],
#        [0.4034749 ],
#        [0.4131274 ],
#        [0.52123547],
#        [0.5965251 ],
#        [0.58108103],
#        [0.484556  ],
#        [0.3899614 ],
#        [0.3223938 ],
#        [0.3899614 ],
#        [0.4073359 ],
#        [0.3803089 ],
#        [0.48648646],
#        [0.47104248],
#        [0.484556  ],
#        [0.6138996 ],
#        [0.6969112 ],
#        [0.70077217],
#        [0.57915056],
#        [0.46911195],
#        [0.38803086],
#        [0.44787642],
#        [0.45559844],
#        [0.4131274 ],
#        [0.4980695 ],
#        [0.47104248],
#        [0.49999997],
#        [0.6389961 ],
#        [0.7471043 ],
#        [0.7741313 ],
#        [0.57915056],
#        [0.492278  ],
#        [0.3976834 ],
#        [0.44980696],
#        [0.49420848],
#        [0.45945945],
#        [0.5830116 ],
#        [0.5637065 ],
#        [0.61003864],
#        [0.71042466],
#        [0.8571429 ],
#        [0.8783784 ],
#        [0.69305015],
#        [0.5849421 ],
#        [0.4980695 ],
#        [0.58108103],
#        [0.6042471 ],
#        [0.554054  ],
#        [0.60810804],
#        [0.6891892 ],
#        [0.71042466],
#        [0.8320464 ],
#        [1.        ],
#        [0.96911204],
#        [0.7799227 ],
#        [0.6891892 ],
#        [0.55212355],
#        [0.6332046 ]], dtype=float32)

# %%
trainX.shape
# Out:
# (92, 1, 3)

# %%
# 訓練模型


from keras.layers import GRU, Dense

# 建立 GRU 模型
model_gru = Sequential()
model_gru.add(GRU(50, input_shape=(1, look_back)))
model_gru.add(Dense(1))
model_gru.compile(loss='mean_squared_error', optimizer='adam')

# 訓練 GRU 模型
model_gru.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)


# 模型評估
trainPredict = model_gru.predict(trainX)
testPredict = model_gru.predict(testX)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0425
# Epoch 2/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0049
# Epoch 3/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0055
# Epoch 4/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033
# Epoch 5/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0037
# Epoch 6/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0033
# Epoch 7/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031
# Epoch 8/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040
# Epoch 9/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0030
# Epoch 10/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046
# Epoch 11/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023
# Epoch 12/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025
# Epoch 13/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0030
# Epoch 14/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024
# Epoch 15/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028
# Epoch 16/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0024
# Epoch 17/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018
# Epoch 18/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0028
# Epoch 19/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0031
# Epoch 20/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0020
# Epoch 21/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028
# Epoch 22/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024
# Epoch 23/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0019
# Epoch 24/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0026
# Epoch 25/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 26/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0023
# Epoch 27/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 28/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 29/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0022
# Epoch 30/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0019
# Epoch 31/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024
# Epoch 32/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0021
# Epoch 33/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0016
# Epoch 34/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0025
# Epoch 35/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018
# Epoch 36/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017
# Epoch 37/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 38/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023
# Epoch 39/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028
# Epoch 40/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 41/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 42/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017
# Epoch 43/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 44/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 45/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023
# Epoch 46/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 47/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017
# Epoch 48/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 49/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018
# Epoch 50/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016
# Epoch 51/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0023
# Epoch 52/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0016
# Epoch 53/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0020
# Epoch 54/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021
# Epoch 55/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029
# Epoch 56/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0013
# Epoch 57/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 58/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020
# Epoch 59/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016
# Epoch 60/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019
# Epoch 61/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025
# Epoch 62/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0021
# Epoch 63/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024
# Epoch 64/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0020
# Epoch 65/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 66/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020
# Epoch 67/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 68/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018
# Epoch 69/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 70/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015
# Epoch 71/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025
# Epoch 72/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0017
# Epoch 73/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0014
# Epoch 74/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0023
# Epoch 75/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 76/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019
# Epoch 77/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 78/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 79/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 80/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0017
# Epoch 81/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019
# Epoch 82/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016
# Epoch 83/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 84/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0020
# Epoch 85/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 86/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012
# Epoch 87/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 88/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0018
# Epoch 89/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017
# Epoch 90/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 91/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019
# Epoch 92/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 93/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 94/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 95/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 96/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024
# Epoch 97/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0015
# Epoch 98/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0021
# Epoch 99/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0020
# Epoch 100/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0019
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
print(trainPredict.shape)
print(trainY.shape)
print(testPredict.shape)
print(testY.shape)
# Out:
# (90, 1)
# (90, 1)
# (42, 1)
# (42, 1)

# %%
from sklearn.metrics import mean_squared_error
import math


# 還原常態化的訓練資料
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY.reshape(-1, 1)) # 將 trainY 轉換為二維數組
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY.reshape(-1, 1)) # 將 testY 轉換為二維數組


# 計算 RMSE
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))


# 訓練資料的 X/Y
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# 測試資料 X/Y
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# 繪圖
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 31807551406.41 RMSE
# Test Score: 13379252.40 RMSE

# %% [markdown]
# ## 改變落後期數(Time Steps)：X由t-1期改為t-3期(單期)

# %%
# 載入測試資料
df = pd.read_csv('./RNN/monthly-airline-passengers.csv', usecols=[1])

dataset = df.values
dataset = dataset.astype('float32')

# X 常態化
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# 資料分割
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# 以前期資料為 X，當前期資料為 Y
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# 轉換為三維 [筆數, 落後期數, X維度]
# trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
# testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
trainX.shape
# Out:
# (92, 3, 1)

# %%
# 訓練模型
model = Sequential()
# (1, look_back) 改為 (look_back, 1)
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)

# 模型評估
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 2s 3ms/step - loss: 0.0282
# Epoch 2/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 3/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 4/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 5/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 6/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 7/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 8/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 9/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 10/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 11/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 12/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 13/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 14/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0050
# Epoch 15/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 16/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0049
# Epoch 17/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 18/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 19/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 20/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 21/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 22/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 23/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 24/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 25/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 26/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 27/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 28/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 29/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 30/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 31/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 32/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 33/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 34/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 35/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 36/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 37/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0046
# Epoch 38/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 39/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 40/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 41/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 42/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 43/100
# 92/92 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 44/100
# 92/92 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 45/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 46/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 47/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 48/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 49/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 50/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 51/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 52/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 53/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 54/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 55/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 56/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 57/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 58/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 59/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 60/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 61/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 62/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 63/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 64/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 65/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 66/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 67/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 68/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 69/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 70/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 71/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 72/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 73/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 74/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 75/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 76/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 77/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 78/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 79/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 80/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 81/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 82/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 83/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 84/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 85/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 86/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 87/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 88/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 89/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 90/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 91/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 92/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 93/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 94/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 95/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 96/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 97/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 98/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 99/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 100/100
# 92/92 [==============================] - 0s 3ms/step - loss: 0.0023

# %%
from sklearn.metrics import mean_squared_error
import math

# 還原常態化的訓練資料
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# 計算 RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# 訓練資料的 X/Y
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# 測試資料 X/Y
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# 繪圖
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 24.79 RMSE
# Test Score: 52.74 RMSE

# %% [markdown]
# ## stateful=True

# %%
# 載入測試資料
df = pd.read_csv('./RNN/monthly-airline-passengers.csv', usecols=[1])

dataset = df.values
dataset = dataset.astype('float32')

# X 常態化
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# 資料分割
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# 以前期資料為 X，當前期資料為 Y
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# 轉換為三維 [筆數, 落後期數, X維度]
# trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
# testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
# 訓練模型
model = Sequential()
# (1, look_back) 改為 (look_back, 1)
# model.add(LSTM(4, input_shape=(look_back, 1)))
batch_size = 1
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
# model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)
for i in range(100):
    model.fit(trainX, trainY, epochs=1, batch_size=batch_size,
              shuffle=False, verbose=2)
    # 重置狀態(cell state)
    model.reset_states()

# 模型評估
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# Out:
# 92/92 - 2s - loss: 0.0052
# 92/92 - 0s - loss: 0.0085
# 92/92 - 0s - loss: 0.0069
# 92/92 - 0s - loss: 0.0057
# 92/92 - 0s - loss: 0.0051
# 92/92 - 0s - loss: 0.0049
# 92/92 - 0s - loss: 0.0048
# 92/92 - 0s - loss: 0.0047
# 92/92 - 0s - loss: 0.0047
# 92/92 - 0s - loss: 0.0047
# 92/92 - 0s - loss: 0.0047
# 92/92 - 0s - loss: 0.0046
# 92/92 - 0s - loss: 0.0046
# 92/92 - 0s - loss: 0.0046
# 92/92 - 0s - loss: 0.0046
# 92/92 - 0s - loss: 0.0031
# 92/92 - 0s - loss: 0.0031
# 92/92 - 0s - loss: 0.0031
# 92/92 - 0s - loss: 0.0030
# 92/92 - 0s - loss: 0.0030
# 92/92 - 0s - loss: 0.0030
# 92/92 - 0s - loss: 0.0030
# 92/92 - 0s - loss: 0.0030
# 92/92 - 0s - loss: 0.0029
# 92/92 - 0s - loss: 0.0029
# 92/92 - 0s - loss: 0.0029
# 92/92 - 0s - loss: 0.0029

# %%
from sklearn.metrics import mean_squared_error
import math

# 還原常態化的訓練資料
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# 計算 RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# 訓練資料的 X/Y
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# 測試資料 X/Y
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# 繪圖
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Train Score: 27.54 RMSE
# Test Score: 63.90 RMSE

# %% [markdown]
# ## Stacked LSTM

# %%
# 載入測試資料
df = pd.read_csv('./RNN/monthly-airline-passengers.csv', usecols=[1])

dataset = df.values
dataset = dataset.astype('float32')

# X 常態化
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# 資料分割
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# 以前期資料為 X，當前期資料為 Y
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# 轉換為三維 [筆數, 落後期數, X維度]
# trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
# testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
# 訓練模型
model = Sequential()
# (1, look_back) 改為 (look_back, 1)
# model.add(LSTM(4, input_shape=(look_back, 1)))
batch_size = 1

# Stacked LSTM
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1),
               stateful=True, return_sequences=True))
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1),
               stateful=True))

model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
# model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=1)
for i in range(100):
    model.fit(trainX, trainY, epochs=1, batch_size=batch_size,
              shuffle=False, verbose=2)
    # 重置狀態(cell state)
    model.reset_states()

# 模型評估
trainPredict = model.predict(trainX, batch_size=batch_size)
# 重置狀態(cell state)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# Out:
# 92/92 - 3s - loss: 0.0049
# 92/92 - 0s - loss: 0.0161
# 92/92 - 0s - loss: 0.0103
# 92/92 - 0s - loss: 0.0073
# 92/92 - 0s - loss: 0.0060
# 92/92 - 0s - loss: 0.0057
# 92/92 - 0s - loss: 0.0058
# 92/92 - 0s - loss: 0.0059
# 92/92 - 0s - loss: 0.0059
# 92/92 - 0s - loss: 0.0059
# 92/92 - 0s - loss: 0.0059
# 92/92 - 0s - loss: 0.0059
# 92/92 - 0s - loss: 0.0059
# 92/92 - 0s - loss: 0.0058
# 92/92 - 0s - loss: 0.0058
# 92/92 - 0s - loss: 0.0058
# 92/92 - 0s - loss: 0.0058
# 92/92 - 0s - loss: 0.0058
# 92/92 - 0s - loss: 0.0057
# 92/92 - 0s - loss: 0.0057
# 92/92 - 0s - loss: 0.0057
# 92/92 - 0s - loss: 0.0057
# 92/92 - 0s - loss: 0.0056
# 92/92 - 0s - loss: 0.0056
# 92/92 - 0s - loss: 0.0056
# 92/92 - 0s - loss: 0.0056
# 92/92 - 0s - loss: 0.0055
# 92/92 - 0s - loss: 0.0055
# 92/92 - 0s - loss: 0.0055
# 92/92 - 0s - loss: 0.0054
# 92/92 - 0s - loss: 0.0054
# 92/92 - 0s - loss: 0.0053
# 92/92 - 0s - loss: 0.0053
